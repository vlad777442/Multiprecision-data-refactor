# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
file_path = 'packet_loss_data8192nosleep.csv'
packet_loss_data = pd.read_csv(file_path)
packet_loss_data['packet_loss_rate'] = packet_loss_data['packet_loss_rate'].apply(lambda x: x * 1000)

plt.figure(figsize=(8, 4))
plt.hist(packet_loss_data['packet_loss_rate'], bins=10000, color='skyblue', edgecolor='black')
plt.title('Histogram of Packet Loss 8192')
plt.xlabel('Packet Loss Rate')
plt.ylabel('Frequency')
plt.grid(axis='y', alpha=0.75)
plt.xlim(0, 50)

plt.show()

# %%
packet_loss_data['packet_loss_rate'].describe()
# Out:
# count    7169.000000
# mean        2.967032
# std        57.098799
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max      3119.050000
# Name: packet_loss_rate, dtype: float64

# %%
packet_loss_data['packet_loss_rate'].quantile(0.95)
# Out:
# 0.0

# %%
file_path = 'packet_loss_data8192nosleep (3).csv'
packet_loss_data = pd.read_csv(file_path)
packet_loss_data['packet_loss_rate'] = packet_loss_data['packet_loss_rate'].apply(lambda x: x * 1000)

plt.figure(figsize=(8, 4))
plt.hist(packet_loss_data['packet_loss_rate'], bins=10000, color='skyblue', edgecolor='black')
plt.title('Histogram of Packet Loss 8192')
plt.xlabel('Packet Loss Rate')
plt.ylabel('Frequency')
plt.grid(axis='y', alpha=0.75)
plt.xlim(0, 50)

plt.show()

# %%
packet_loss_data['packet_loss_rate'].describe()
# Out:
# count    3586.000000
# mean        3.577272
# std        52.175774
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max      1814.810000
# Name: packet_loss_rate, dtype: float64

# %%
packet_loss_data['packet_loss_rate'].quantile(0.95)
# Out:
# 0.0
